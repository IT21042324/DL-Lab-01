# %% [markdown]
# # Task 1

# %% [markdown]
# #### 1. Create a random 4x4 array from an exponential distribution. Refer numpy functions.

# %%
import numpy as np

np.random.seed(42)
arr = np.random.exponential(scale=1.0, size=(4, 4))
print(arr)
# Out:
# [[0.46926809 3.01012143 1.31674569 0.91294255]
#  [0.16962487 0.16959629 0.05983877 2.01123086]
#  [0.91908215 1.23125006 0.02079931 3.50355748]
#  [1.78642954 0.23868763 0.20067899 0.20261142]]

# %% [markdown]
# #### 2. Create a random 100000x1 array from the same exponential distribution and visualize the distribution histogram along with uniform and normal distributions. Use the code given below and do the necessary changes. Change the number of bins and the plot view to make the visualization better.

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
# plt.axis([-2.5, 2.5, 0, 1.1])
# plt.legend(loc = "upper left")
# plt.title("Random distributions")
# plt.xlabel("Value")
# plt.ylabel("Density")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Create arrays
size = 100000
exponential_data = np.random.exponential(size=size)
uniform_data = np.random.rand(size)
normal_data = np.random.normal(size=size)

# Create the plot
plt.figure(figsize=(12, 8))

# Plot histograms
bins = 100
plt.hist(np.random.rand(100000), density=True, bins=bins, histtype="step", color="blue", label="rand")
plt.hist(normal_data, density=True, bins=bins, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=bins, histtype="step", color="red", label="Exponential")

# Adjust the plot view
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc="upper right")
plt.title("Distributions Comparison")
plt.xlabel("Value")
plt.ylabel("Density")

# Show the plot
plt.show()

# %% [markdown]
# ### Changing the number of bins - observation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Create arrays
size = 100000
exponential_data = np.random.exponential(size=size)
uniform_data = np.random.rand(size)
normal_data = np.random.normal(size=size)

# Create the plot
plt.figure(figsize=(12, 8))

# Plot histograms
bins = 22
plt.hist(np.random.rand(100000), density=True, bins=bins, histtype="step", color="blue", label="rand")
plt.hist(normal_data, density=True, bins=bins, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=bins, histtype="step", color="red", label="Exponential")

# Adjust the plot view
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc="upper right")
plt.title("Distributions Comparison")
plt.xlabel("Value")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(12, 8))

# Plot histograms
bins = 200
plt.hist(np.random.rand(100000), density=True, bins=bins, histtype="step", color="blue", label="rand")
plt.hist(normal_data, density=True, bins=bins, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=bins, histtype="step", color="red", label="Exponential")

# Adjust the plot view
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc="upper right")
plt.title("Distributions Comparison")
plt.xlabel("Value")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(12, 8))

# Plot histograms
bins = 200
plt.hist(np.random.rand(100000), density=True, bins=bins, histtype="step", color="blue", label="rand")
plt.hist(normal_data, density=True, bins=bins, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=bins, histtype="step", color="red", label="Exponential")

# Adjust the plot view
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc="upper right")
plt.title("Distributions Comparison")
plt.xlabel("Value")
plt.ylabel("Density")

# Show the plot
plt.show()

# %% [markdown]
# ### 3. Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5].

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create data
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# Create the figure and 3D axis
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surface = ax.plot_surface(X, Y, Z, cmap='coolwarm', linewidth=0.1)

# Add a color bar
fig.colorbar(surface, shrink=0.5, aspect=5)

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set title
ax.set_title('Z = X^2 + Y^2')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from mpl_toolkits.mplot3d import Axes3D
#       5 # Create data
#       6 x = np.linspace(-5, 5, 50)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\mpl_toolkits\mplot3d\__init__.py:1
# ----> 1 from .axes3d import Axes3D
#       3 __all__ = ['Axes3D']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:45
#      38 from . import proj3d
#      39 from . import axis3d
#      42 @_docstring.interpd
#      43 @_api.define_aliases({
#      44     "xlim": ["xlim3d"], "ylim": ["ylim3d"], "zlim": ["zlim3d"]})
# ---> 45 class Axes3D(Axes):
#      46     """
#      47     3D Axes object.
#      48     """
#      49     name = '3d'
#
# ...

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
# Out:
# array([[-5.        , -5.        , -5.        , ..., -5.        ,
#         -5.        , -5.        ],
#        [-4.79591837, -4.79591837, -4.79591837, ..., -4.79591837,
#         -4.79591837, -4.79591837],
#        [-4.59183673, -4.59183673, -4.59183673, ..., -4.59183673,
#         -4.59183673, -4.59183673],
#        ...,
#        [ 4.59183673,  4.59183673,  4.59183673, ...,  4.59183673,
#          4.59183673,  4.59183673],
#        [ 4.79591837,  4.79591837,  4.79591837, ...,  4.79591837,
#          4.79591837,  4.79591837],
#        [ 5.        ,  5.        ,  5.        , ...,  5.        ,
#          5.        ,  5.        ]])
